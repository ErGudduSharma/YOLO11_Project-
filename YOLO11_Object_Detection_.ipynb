# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
### load the model
model = YOLO("yolo11n.pt")

# %%
### Perform Ojbect Detection
rs = model("/content/random-people-in-munich-HRFF41.jpg")
# Out:
# image 1/1 /content/random-people-in-munich-HRFF41.jpg: 480x640 8 persons, 1 traffic light, 1 backpack, 1 suitcase, 49.8ms
# Speed: 11.7ms preprocess, 49.8ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)

# %%
rs[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=1300x956>

# %%
rs = model("/content/lviv-ukraine-03242024-kpop-random-260nw-2444984671.webp")
rs[0].show()
# Out:
# image 1/1 /content/lviv-ukraine-03242024-kpop-random-260nw-2444984671.webp: 480x640 16 persons, 1 handbag, 12.2ms
# Speed: 5.4ms preprocess, 12.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=390x280>

# %%
rs = model("/content/images.jpeg")
rs[0].show()
# Out:
# image 1/1 /content/images.jpeg: 480x640 6 persons, 8 cars, 5 buss, 1 truck, 11.4ms
# Speed: 2.2ms preprocess, 11.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=259x194>

# %%
### Perform object detection on video or mp4

# %%
rs = model("/content/WhatsApp Video 2025-12-03 at 2.26.44 PM.mp4" , save=True)
rs[0].show()
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/40) /content/WhatsApp Video 2025-12-03 at 2.26.44 PM.mp4: 640x512 9 persons, 1 baseball bat, 51.5ms
# video 1/1 (frame 2/40) /content/WhatsApp Video 2025-12-03 at 2.26.44 PM.mp4: 640x512 10 persons, 8.8ms
# video 1/1 (frame 3/40) /content/WhatsApp Video 2025-12-03 at 2.26.44 PM.mp4: 640x512 12 persons, 1 baseball bat, 7.3ms
# ...
